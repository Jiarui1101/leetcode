# %% [markdown]
# > 回溯三问：
# > 1. 当前操作是什么？
# > 2. 子问题是什么？
# > 3. 下一个子问题是什么？
#
# > 回溯问题的模板——子集形问题
#
# ```
# def answer(nums):
#     ans = []
#     path = []
#     n = len(nums)
#
#     def dfs(i):
#         if i == n:
#
#             return
#
#
#     dfs(0)
#     retuen ans
#
# ```

# %% [markdown]
# # 17. 电话号码的字母组合

# %% [markdown]
# 给定一个仅包含数字 2-9 的字符串，返回所有它能表示的字母组合。答案可以按 任意顺序 返回。
#
# 给出数字到字母的映射如下（与电话按键相同）。注意 1 不对应任何字母。
#
#
# ![image.png](attachment:image.png)
#
#
# 示例 1：
#
# 输入：digits = "23"
# 输出：["ad","ae","af","bd","be","bf","cd","ce","cf"]
# 示例 2：
#
# 输入：digits = ""
# 输出：[]
# 示例 3：
#
# 输入：digits = "2"
# 输出：["a","b","c"]
#
#
# 提示：
#
# 0 <= digits.length <= 4
# digits[i] 是范围 ['2', '9'] 的一个数字。

# %%
MAPPING = ['', '', 'abc', 'def', 'ghi', 'jkl', 'mno', 'pqrs', 'tuv', 'wxyz']

def f17(digits):
    n = len(digits)
    ans, path = [], ['']*n
    
    if n == 0: return []
    
    # > 1. 当前操作是什么？用path记录字符串组合，枚举path[i]应该是哪一个字母  
    # > 2. 子问题是什么？枚举下标 >= i 的剩余部分，记为dfs(i)。从dfs(0)开始
    # > 3. 下一个子问题是什么？  枚举 >= i+1 直到最后一个i == n == len(digits)
    def dfs(i):
        if i == n:
            ans.append(''.join(path))
            return
        for c in MAPPING[int(digits[i])]:
            path[i] = c
            dfs(i+1)
    dfs(0)
    return ans

digits = "23"
f17(digits)
# Out:
# ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']

# %%
MAPPING = ['', '', 'abc', 'def', 'ghi', 'jkl', 'mno', 'pqrs', 'tuv', 'wxyz']

def f17(digits):
    n = len(digits)
    ans, path = [], []
    
    if n == 0: return []
    
    # > 1. 当前操作是什么？用path记录字符串组合，枚举path[i]应该是哪一个字母  
    # > 2. 子问题是什么？枚举下标 >= i 的剩余部分，记为dfs(i)。从dfs(0)开始
    # > 3. 下一个子问题是什么？  枚举 >= i+1 直到最后一个i == n == len(digits)
    def dfs(i):
        if i == n:
            ans.append(''.join(path))
            return
        for c in MAPPING[int(digits[i])]:
            path.append(c)
            dfs(i+1)
    dfs(0)
    return ans

digits = "23"
f17(digits)
# Out:
# ['ad',
#  'ade',
#  'adef',
#  'adefbd',
#  'adefbde',
#  'adefbdef',
#  'adefbdefcd',
#  'adefbdefcde',
#  'adefbdefcdef']

# %%
MAPPING = ['', '', 'abc', 'def', 'ghi', 'jkl', 'mno', 'pqrs', 'tuv', 'wxyz']

def f17(digits):
    n = len(digits)
    ans, path = [], []
    
    if n == 0: return []
    
    # > 1. 当前操作是什么？用path记录字符串组合，枚举path[i]应该是哪一个字母  
    # > 2. 子问题是什么？枚举下标 >= i 的剩余部分，记为dfs(i)。从dfs(0)开始
    # > 3. 下一个子问题是什么？  枚举 >= i+1 直到最后一个i == n == len(digits)
    def dfs(i):
        if i == n:
            ans.append(''.join(path))#ans.append(path.copy())
            return
        for c in MAPPING[int(digits[i])]:
            path.append(c)
            dfs(i+1)
            path.pop()
    dfs(0)
    return ans

digits = "23"
f17(digits)
# Out:
# ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']

# %% [markdown]
# # 78. 子集

# %% [markdown]
# 给你一个整数数组 nums ，数组中的元素 互不相同 。返回该数组所有可能的
# 子集
# （幂集）。
#
# 解集 不能 包含重复的子集。你可以按 任意顺序 返回解集。
#
#
#
# 示例 1：
#
# 输入：nums = [1,2,3]
# 输出：[[],[1],[2],[1,2],[3],[1,3],[2,3],[1,2,3]]
#
# 示例 2：
#
# 输入：nums = [0]
# 输出：[[],[0]]
#
#
# 提示：
#
# 1 <= nums.length <= 10
# -10 <= nums[i] <= 10
# nums 中的所有元素 互不相同

# %%
# 方法一：过程视角
def f78(nums):
    ans, path = [], []
    n = len(nums)
    if n == 0:return []
    def dfs(i):
        # dfs 中的 i 表示当前考虑到 nums[i] 选或不选。
        if i == n:
            ans.append(path.copy())
            return
        path.append(nums[i])
        dfs(i+1)
        path.pop()

        dfs(i+1)
        
    dfs(0)
    return ans

nums = [1,2,3]
f78(nums)
# Out:
# [[1, 2, 3], [1, 2], [1, 3], [1], [2, 3], [2], [3], []]

# %%
# 方法二：结果视角
def f78(nums):
    ans, path = [], []
    n = len(nums)
    if n == 0: return []
    def dfs(i):
        # dfs 中的 i 表示现在要枚举选 nums[i] 到 nums[n−1] 中的一个数，添加到 path 末尾。
        # if i == n:
        #     return
        ans.append(path.copy())
        for j in range(i, n):
            path.append(nums[j])
            dfs(j+1)
            path.pop()
        
    dfs(0)
    return ans

nums = [1,2,3]
f78(nums)
# Out:
# [[], [1], [1, 2], [1, 2, 3], [1, 3], [2], [2, 3], [3]]

# %%
# 没掌握的二进制方法
def f78(nums):
    ans = []
    for i in range(1 << len(nums)):
        subset = [x for j, x  in enumerate(nums) if i >> j & 1]
        ans.append(subset)
    return ans
nums = [1,2,3]
f78(nums)
# Out:
# [[], [1], [2], [1, 2], [3], [1, 3], [2, 3], [1, 2, 3]]

# %% [markdown]
# # 131. 分割回文串

# %% [markdown]
# 给你一个字符串 s，请你将 s 分割成一些子串，使每个子串都是
# 回文串
#  。返回 s 所有可能的分割方案。
#
#
#
# 示例 1：
#
# 输入：s = "aab"
# 输出：[["a","a","b"],["aa","b"]]
# 示例 2：
#
# 输入：s = "a"
# 输出：[["a"]]
#
#
# 提示：
#
# 1 <= s.length <= 16
# s 仅由小写英文字母组成

# %%
# 方法一：过程视角
def f131(s):
    ans, path = [], []
    n = len(s)
    if s == 1:return [[s]]
    
    def dfs(i, start):
        # dfs 中的 i 表示当前考虑到 nums[i] 选或不选。
        # start 表示当前这段回文子串的开始位置
        if i == n:
            ans.append(path.copy())
            return 

        # 不选 i 和 i+1 之间的逗号（i=n-1 时一定要选）
        if i < n - 1:
            dfs(i + 1, start)

        # 选 i 和 i+1 之间的逗号（把 s[i] 作为子串的最后一个字符）
        t = s[start: i + 1]
        if t == t[::-1]:  # 判断是否回文
            path.append(t)
            dfs(i + 1, i + 1)  # 下一个子串从 i+1 开始
            path.pop()  # 恢复现场

    dfs(0,0)
    return ans
s = "aab"
f131(s)
# Out:
# [['aa', 'b'], ['a', 'a', 'b']]

# %%
# 方法二：结果视角
def f131(s):
    ans, path = [], []
    n = len(s)
    if s == 1:return [[s]]
    def dfs(i):
        # dfs 中的 i 表示现在要枚举选 s[i] 到 s[n−1] 中的一个字符，添加到 path 末尾。
        if i == n:
            ans.append(path.copy())
            return 
        for j in range(i, n):
            t = s[i:j+1]
            if t == t[::-1]:
                path.append(t)
                dfs(j+1)
                path.pop()
    dfs(0)
    return ans
s = "aab"
f131(s)
# Out:
# [['a', 'a', 'b'], ['aa', 'b']]
